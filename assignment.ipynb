# %%
# !pip install yfinance
# !pip install bs4
# !pip install nbformat
# !pip install --upgrade plotly
# Out:
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 3.0/3.0 MB 22.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 24.6 MB/s eta 0:00:00
# ...
#   Created wheel for peewee: filename=peewee-3.18.1-py3-none-any.whl size=139100 sha256=ad615f2d8e78c45cac516f0f2ff839bf9995e3e7773f8e51d7c217046d6cee4d
#   Stored in directory: c:\users\alpha's\appdata\local\pip\cache\wheels\1a\57\6a\bb71346381d0d911cd4ce3026f1fa720da76707e4f01cf27dd
# Successfully built peewee
# ...

# %%
import yfinance as yf

# Create ticker object for Tesla
tsla = yf.Ticker("TSLA")

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
tesla = yf.Ticker("TSLA")


tesla_data = tesla.history(period="max")


tesla_data.reset_index(inplace=True)


print(tesla_data.head())
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %%
# Question 1: Extract Tesla stock data using yfinance
import yfinance as yf
import pandas as pd

def get_tesla_stock_data(period="max"):
    tesla = yf.Ticker("TSLA")
    df = tesla.history(period=period)
    df.reset_index(inplace=True)
    return df

if __name__ == "__main__":
    tesla_stock = get_tesla_stock_data()
    print(tesla_stock.head())
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %%
pip install requests pandas beautifulsoup4 lxml html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install requests pandas beautifulsoup4 lxml html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install html5lib beautifulsoup4 lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib beautifulsoup4 lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def get_tesla_revenue():
    url = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                      "AppleWebKit/537.36 (KHTML, like Gecko) "
                      "Chrome/114.0.0.0 Safari/537.36"
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    html = response.text

    from io import StringIO
    import pandas as pd

    tables = pd.read_html(StringIO(html))

    print(f"Found {len(tables)} tables")

    for i, table in enumerate(tables):
        print(f"\nTable {i} columns:")
        print(table.columns)
        print(table.head(3))
    
    # Just for now, return None so you can inspect
    return None

if __name__ == "__main__":
    get_tesla_revenue()
# Out:
# Found 6 tables
#
# Table 0 columns:
# Index(['Tesla Annual Revenue (Millions of US $)', 'Tesla Annual Revenue (Millions of US $).1'], dtype='object')
#    Tesla Annual Revenue (Millions of US $)  \
# 0                                     2024
# 1                                     2023
# 2                                     2022
#
#   Tesla Annual Revenue (Millions of US $).1
# 0                                   $97,690
# 1                                   $96,773
# 2                                   $81,462
#
# Table 1 columns:
# Index(['Tesla Quarterly Revenue (Millions of US $)', 'Tesla Quarterly Revenue (Millions of US $).1'], dtype='object')
#   Tesla Quarterly Revenue (Millions of US $)  \
# 0                                 2025-03-31
# 1                                 2024-12-31
# 2                                 2024-09-30
#
#   Tesla Quarterly Revenue (Millions of US $).1
# 0                                      $19,335
# ...

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# Define the ticker symbol
ticker_symbol = "GME"

# Get the data for GameStop
gme_data = yf.Ticker(ticker_symbol)

# Download historical market data
historical_data = gme_data.history(period="1y")

# Print 
print(historical_data.head())
# Out:
#                                 Open   High        Low      Close    Volume  \
# Date
# 2024-05-17 00:00:00-04:00  21.860001  22.41  19.700001  22.209999  96079600
# 2024-05-20 00:00:00-04:00  21.540001  23.40  18.940001  23.139999  55261600
# 2024-05-21 00:00:00-04:00  22.240000  22.85  20.040001  22.120001  49250100
# 2024-05-22 00:00:00-04:00  21.559999  22.25  20.760000  21.120001  43521400
# 2024-05-23 00:00:00-04:00  21.400000  21.40  18.260000  18.320000  30561100
#
#                            Dividends  Stock Splits
# Date
# 2024-05-17 00:00:00-04:00        0.0           0.0
# 2024-05-20 00:00:00-04:00        0.0           0.0
# 2024-05-21 00:00:00-04:00        0.0           0.0
# 2024-05-22 00:00:00-04:00        0.0           0.0
# 2024-05-23 00:00:00-04:00        0.0           0.0

# %%
pip install requests beautifulsoup4 pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)"
                  " Chrome/90.0.4430.93 Safari/537.36"
}
response = requests.get(url, headers=headers)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)"
                  " Chrome/90.0.4430.93 Safari/537.36"
}

response = requests.get(url, headers=headers)

if response.status_code != 200:
    raise Exception(f"Failed to load page {url}, status code: {response.status_code}")

soup = BeautifulSoup(response.text, "html.parser")

tables = soup.find_all("table", {"class": "historical_data_table"})

if not tables:
    raise Exception("No revenue tables found on the page.")

revenue_table = tables[0]

rows = revenue_table.find_all("tr")

dates = []
revenues = []

for row in rows[1:]:
    cols = row.find_all("td")
    if len(cols) >= 2:
        dates.append(cols[0].text.strip())
        revenues.append(cols[1].text.strip())

df = pd.DataFrame({
    "Date": dates,
    "Revenue": revenues
})

df["Revenue"] = df["Revenue"].str.replace("$", "").str.replace(",", "").astype(float)

print(df)

df.to_csv("gamestop_revenue.csv", index=False)
# Out:
#     Date  Revenue
# 0   2025   3823.0
# 1   2024   5273.0
# 2   2023   5927.0
# 3   2022   6011.0
# 4   2021   5090.0
# 5   2020   6466.0
# 6   2019   8285.0
# 7   2018   8547.0
# 8   2017   7965.0
# 9   2016   9364.0
# 10  2015   9296.0
# 11  2014   9040.0
# 12  2013   8887.0
# 13  2012   9551.0
# 14  2011   9474.0
# 15  2010   9078.0
# 16  2009   8806.0

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Step 1: Download Tesla stock data
tesla_data = yf.download('TSLA', start='2020-01-01', end='2023-01-01')
tesla_data = tesla_data.reset_index()  # Reset index to get Date as a column

# Step 2: Define the plotting function
def make_graph(df, title):
    plt.figure(figsize=(12,6))
    plt.plot(df['Date'], df['Close'], label='Close Price')
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# Step 3: Plot Tesla stock data
make_graph(tesla_data, "Tesla Stock Closing Prices")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Step 1: Download GameStop stock data
gme_data = yf.download('GME', start='2020-01-01', end='2023-01-01')
gme_data = gme_data.reset_index()  # Reset index to get Date as a column

# Assuming the make_graph function is defined as before:
def make_graph(df, title):
    plt.figure(figsize=(12,6))
    plt.plot(df['Date'], df['Close'], label='Close Price')
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# Step 2: Plot GameStop stock data
make_graph(gme_data, "GameStop Stock Closing Prices")
# Out:
# [*********************100%***********************]  1 of 1 completed
